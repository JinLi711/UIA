# %% [markdown]
# # Loading Items

# %%
import pandas as pd
import sqlite3

# import sys
# sys.path.insert(0, '../preprocess')

import importlib
import reduce_memory as rm
importlib.reload(rm)

import preprocess
importlib.reload(preprocess)
# Out:
# memory used before preprocess:  9.33704
#
# downcasting integers for: ['mid', 'project_id']
#
# reduced memory usage for:   mid          from     3.11 to     1.56
# reduced memory usage for:   project_id   from     3.11 to     1.56
#
# available RAM: svmem(total=8589934592, available=1821483008, percent=78.8, used=5840125952, free=15355904, active=1821933568, inactive=1806127104, wired=2212065280)
# available RAM: svmem(total=8589934592, available=1821601792, percent=78.8, used=5840125952, free=15474688, active=1821933568, inactive=1806127104, wired=2212065280)
#
# memory used after preprocess:  6.22472
# converting emotion                        size:  26.63	->	 3.36
# converting medium                         size:  26.53	->	 3.36
# memory used before preprocess:  9.33704
#
# downcasting integers for: ['mid', 'project_id']
#
# reduced memory usage for:   mid          from     3.11 to     1.56
# reduced memory usage for:   project_id   from     3.11 to     1.56
#
# available RAM: svmem(total=8589934592, available=1742393344, percent=79.7, used=5624012800, free=255995904, active=1934106624, inactive=1486397440, wired=2203508736)
# available RAM: svmem(total=8589934592, available=1742639104, percent=79.7, used=5624012800, free=256241664, active=1939005440, inactive=1486397440, wired=2198609920)
#
# memory used after preprocess:  6.22472
# converting attribute                      size:  30.9	->	 3.54
# converting label                          size:  28.52	->	 3.54
# <module 'preprocess' from '../preprocess/preprocess.py'>

# %%
connection = sqlite3.connect("../data/bam-crowd-only.sqlite")
c = connection.cursor()

# %% [markdown]
# ## Loading URLS

# %%
modules = pd.read_sql(
    "select * from modules",
    connection
)

# %%
modules.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389040 entries, 0 to 389039
# Data columns (total 5 columns):
# mid               389040 non-null int64
# project_id        389040 non-null int64
# src               389040 non-null object
# mature_content    389040 non-null int64
# license           389040 non-null object
# dtypes: int64(3), object(2)
# memory usage: 14.8+ MB

# %%
modules.head()
# Out:
#     mid  project_id                                                src  \
# 0   489       40030  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1  1004       40040  https://mir-s3-cdn-cf.behance.net/project_modu...
# 2  1053       40041  https://mir-s3-cdn-cf.behance.net/project_modu...
# 3  1065       40041  https://mir-s3-cdn-cf.behance.net/project_modu...
# 4  1067       40043  https://mir-s3-cdn-cf.behance.net/project_modu...
#
#    mature_content   license
# 0               0  cc by-nc
# 1               0  cc by-nc
# 2               0  cc by-nc
# 3               0  cc by-nc
# 4               0  cc by-nc

# %%
modules.drop(['mature_content', 'license'], axis=1, inplace=True)

# %%
modules.head()
# Out:
#     mid  project_id                                                src
# 0   489       40030  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1  1004       40040  https://mir-s3-cdn-cf.behance.net/project_modu...
# 2  1053       40041  https://mir-s3-cdn-cf.behance.net/project_modu...
# 3  1065       40041  https://mir-s3-cdn-cf.behance.net/project_modu...
# 4  1067       40043  https://mir-s3-cdn-cf.behance.net/project_modu...

# %%
modules.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389040 entries, 0 to 389039
# Data columns (total 3 columns):
# mid           389040 non-null int64
# project_id    389040 non-null int64
# src           389040 non-null object
# dtypes: int64(2), object(1)
# memory usage: 8.9+ MB

# %%
modules_compressed = rm.compress_X(modules, {'src'})
# Out:
# memory used before preprocess:  7.780799999999999
#
# downcasting integers for: ['project_id']
#
# reduced memory usage for:   project_id   from     4.67 to     4.67
#
# available RAM: svmem(total=8589934592, available=1790660608, percent=79.2, used=5702856704, free=150130688, active=1715503104, inactive=1640529920, wired=2346823680)
# available RAM: svmem(total=8589934592, available=1769201664, percent=79.4, used=5723856896, free=128671744, active=1699094528, inactive=1640529920, wired=2384232448)
#
# memory used after preprocess:  7.780799999999999

# %%
modules_compressed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389040 entries, 0 to 389039
# Data columns (total 3 columns):
# mid           389040 non-null int32
# project_id    389040 non-null int32
# src           389040 non-null object
# dtypes: int32(2), object(1)
# memory usage: 5.9+ MB

# %%
modules_compressed.set_index('mid')
modules_compressed
# Out:
#            project_id                                                src
# mid
# 489             40030  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1004            40040  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1053            40041  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1065            40041  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1067            40043  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1247            40053  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1248            40053  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1559            40066  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1593            40053  https://mir-s3-cdn-cf.behance.net/project_modu...
# 2240            40168  https://mir-s3-cdn-cf.behance.net/project_modu...
# 2453            40192  https://mir-s3-cdn-cf.behance.net/project_modu...
# 2460            40193  https://mir-s3-cdn-cf.behance.net/project_modu...
# 2475            40197  https://mir-s3-cdn-cf.behance.net/project_modu...
# 2687            40261  https://mir-s3-cdn-cf.behance.net/project_modu...
# 2694            40261  https://mir-s3-cdn-cf.behance.net/project_modu...
# 2944            40294  https://mir-s3-cdn-cf.behance.net/project_modu...
# 3419            40370  https://mir-s3-cdn-cf.behance.net/project_modu...
# 3608            40375  https://mir-s3-cdn-cf.behance.net/project_modu...
# 3686            40390  https://mir-s3-cdn-cf.behance.net/project_modu...
# 3785            40395  https://mir-s3-cdn-cf.behance.net/project_modu...
# 3786            40395  https://mir-s3-cdn-cf.behance.net/project_modu...
# 4094            40479  https://mir-s3-cdn-cf.behance.net/project_modu...
# 4095            40479  https://mir-s3-cdn-cf.behance.net/project_modu...
# 4289            40499  https://mir-s3-cdn-cf.behance.net/project_modu...
# 4526            40541  https://mir-s3-cdn-cf.behance.net/project_modu...
# 4582            40551  https://mir-s3-cdn-cf.behance.net/project_modu...
# 4584            40551  https://mir-s3-cdn-cf.behance.net/project_modu...
# 4588            40541  https://mir-s3-cdn-cf.behance.net/project_modu...
# 5058            40634  https://mir-s3-cdn-cf.behance.net/project_modu...
# 5059            40634  https://mir-s3-cdn-cf.behance.net/project_modu...
# ...               ...                                                ...
# 221201617    22951447  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221233893    22951447  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221250777     3109607  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221276915    11653149  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221296465    12157309  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221311391    26500833  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221317215    27334029  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221342417    27596373  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221347069    27333385  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221411517     1613315  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221422751    27301041  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221483739    10406887  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221538227    30156851  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221615627    29534987  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221655649    24102131  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221655661    24102131  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221666277     9385957  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221710885     7160915  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221805041       97565  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221850181    28750467  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221853487     4686759  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221866595    18094199  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221878323     6045889  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221878325     6045889  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221878327     6045889  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221878331     6045889  https://mir-s3-cdn-cf.behance.net/project_modu...
# 222307913    26742113  https://mir-s3-cdn-cf.behance.net/project_modu...
# 222352655    27827191  https://mir-s3-cdn-cf.behance.net/project_modu...
# 222352657    27827191  https://mir-s3-cdn-cf.behance.net/project_modu...
# 222446005    29445637  https://mir-s3-cdn-cf.behance.net/project_modu...
#
# [389040 rows x 2 columns]

# %% [markdown]
# ## Loading Scores

# %%
scores = pd.read_sql(
    "select * from scores",
    connection,
    index_col="mid"
)

# %%
scores.sort_index(axis=1, inplace=True)

# %%
scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 372777 entries, 489 to 222446005
# Data columns (total 20 columns):
# content_bicycle      372777 non-null float64
# content_bird         372777 non-null float64
# content_building     372777 non-null float64
# content_cars         372777 non-null float64
# content_cat          372777 non-null float64
# content_dog          372777 non-null float64
# content_flower       372777 non-null float64
# content_people       372777 non-null float64
# content_tree         372777 non-null float64
# emotion_gloomy       372777 non-null float64
# emotion_happy        372777 non-null float64
# emotion_peaceful     372777 non-null float64
# emotion_scary        372777 non-null float64
# media_3d_graphics    372777 non-null float64
# media_comic          372777 non-null float64
# media_graphite       372777 non-null float64
# media_oilpaint       372777 non-null float64
# media_pen_ink        372777 non-null float64
# media_vectorart      372777 non-null float64
# media_watercolor     372777 non-null float64
# dtypes: float64(20)
# memory usage: 59.7 MB

# %%
scores.head()
# Out:
#       content_bicycle  content_bird  content_building  content_cars  \
# mid
# 489         -8.194265     -6.825498         -1.033735     -4.741513
# 1004        -5.908639     -7.481776         -2.769971     -8.715858
# 1053        -8.682774    -11.664145         -2.258289     -5.678706
# 1065        -7.429687     -5.884630         -0.526354     -3.525297
# 1067        -6.541219     -6.800467         -2.133614     -4.348733
#
#       content_cat  content_dog  content_flower  content_people  content_tree  \
# mid
# 489    -13.083484    -5.438437       -6.437519       -0.372203     -0.140162
# 1004    -9.379574    -5.466529       -1.974876       -0.110869     -4.740625
# 1053   -23.007246    -9.459610      -15.922831       -0.052687     -9.073513
# 1065    -9.030757    -6.339474       -9.055132       -1.939328     -3.102335
# 1067    -9.875690    -4.610362      -10.881371       -0.225947     -6.983145
#
#       emotion_gloomy  emotion_happy  emotion_peaceful  emotion_scary  \
# mid
# 489        -5.251916      -0.784109         -0.295248     -10.125443
# 1004       -1.939304      -5.214772         -3.770542      -4.781479
# 1053       -1.498988      -4.624222         -3.624131      -3.692783
# 1065       -0.523028      -5.766580         -3.715596      -3.109094
# 1067       -3.240254      -1.745344         -3.466125      -4.812078
#
#       media_3d_graphics  media_comic  media_graphite  media_oilpaint  \
# mid
# 489          -13.048631   -13.372336      -11.520514       -8.102950
# 1004         -10.137968    -9.871041       -8.218750       -9.769642
# 1053          -8.926823    -7.796127       -9.731888       -6.789311
# 1065          -6.108827    -9.137621       -7.905422       -7.122383
# 1067          -9.403267    -8.060266       -7.940952       -8.474461
#
#       media_pen_ink  media_vectorart  media_watercolor
# mid
# 489      -10.792016       -10.279009        -11.912029
# 1004      -9.929028        -9.538937        -17.242306
# 1053      -8.929226        -8.575558        -18.276842
# 1065      -8.709348        -8.250728        -16.156538
# 1067      -7.462641        -8.906570        -14.413774

# %%
scores.columns
'content_bicycle'.split('_')
type (scores)
# Out:
# pandas.core.frame.DataFrame

# %%
def drop_cols(df, col_names, operation):
    """
    Perform an operation to the column if the first part 
    of the name begins with a certain name.
    Ex. The first part of content_bicycle is content
    
    :param df: dataframe 
    :type  df: pandas.core.frame.DataFrame
    :param col_names: string to match
    :type  col_names: str
    :returns: dataframe 
    :rtype:   pandas.core.frame.DataFrame
    """
    
    for col in df.columns:
        if col.split('_')[0] == col_names:
            if operation == "drop":
                df = df.drop([col], axis=1)
            else:
                raise ValueError("Not an avaliable action")
    
    return df
    
# we are not considering content
scores = drop_cols(scores, "content", "drop")
scores.head()
# Out:
#       emotion_gloomy  emotion_happy  emotion_peaceful  emotion_scary  \
# mid
# 489        -5.251916      -0.784109         -0.295248     -10.125443
# 1004       -1.939304      -5.214772         -3.770542      -4.781479
# 1053       -1.498988      -4.624222         -3.624131      -3.692783
# 1065       -0.523028      -5.766580         -3.715596      -3.109094
# 1067       -3.240254      -1.745344         -3.466125      -4.812078
#
#       media_3d_graphics  media_comic  media_graphite  media_oilpaint  \
# mid
# 489          -13.048631   -13.372336      -11.520514       -8.102950
# 1004         -10.137968    -9.871041       -8.218750       -9.769642
# 1053          -8.926823    -7.796127       -9.731888       -6.789311
# 1065          -6.108827    -9.137621       -7.905422       -7.122383
# 1067          -9.403267    -8.060266       -7.940952       -8.474461
#
#       media_pen_ink  media_vectorart  media_watercolor
# mid
# 489      -10.792016       -10.279009        -11.912029
# 1004      -9.929028        -9.538937        -17.242306
# 1053      -8.929226        -8.575558        -18.276842
# 1065      -8.709348        -8.250728        -16.156538
# 1067      -7.462641        -8.906570        -14.413774

# %%
def create_labels(df):
    """
    Create the labels using the scores

    :param df: dataframe 
    :type  df: pandas.core.frame.DataFrame
    :returns: dataframe of the labels
    :rtype:   pandas.core.frame.DataFrame
    """

    emotion_df = pd.DataFrame()
    media_df = pd.DataFrame()

    for col in df.columns:
        if col.split('_')[0] == "emotion":
            emotion_df = pd.concat([emotion_df, df[col]], axis=1)
        if col.split('_')[0] == "media":
            media_df = pd.concat([media_df, df[col]], axis=1)

    emotion_df.rename(
        lambda x: x.split('_')[1],
        axis='columns',
        inplace=True
    )
    media_df.rename(
        lambda x: x.split('_')[1],
        axis='columns',
        inplace=True
    )

    emotion_labels = emotion_df.idxmax(axis=1)
    media_labels = media_df.idxmax(axis=1)

    result = pd.DataFrame({
        "emotion": emotion_labels,
        "medium": media_labels
    })

    result = rm.convert_obj_columns_to_cat(result, {})
#     print (result)
    return result
#     return emotion_labels, media_labels
    # return emotion_df, media_df

# %%
labels = create_labels(scores)
labels.info()
# Out:
# converting emotion                        size:  26.63	->	 3.36
# converting medium                         size:  26.53	->	 3.36
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 372777 entries, 489 to 222446005
# Data columns (total 2 columns):
# emotion    372777 non-null category
# medium     372777 non-null category
# dtypes: category(2)
# memory usage: 3.6 MB

# %%
labels#.head()
# Out:
#             emotion      medium
# mid
# 489        peaceful    oilpaint
# 1004         gloomy    graphite
# 1053         gloomy    oilpaint
# 1065         gloomy          3d
# 1067          happy         pen
# 1247       peaceful    oilpaint
# 1248          scary    oilpaint
# 1559          scary         pen
# 1593          scary    oilpaint
# 2240       peaceful    graphite
# 2453         gloomy    oilpaint
# 2460       peaceful    graphite
# 2475         gloomy    oilpaint
# 2687          happy    oilpaint
# 2944          scary       comic
# 3419       peaceful          3d
# 3608       peaceful  watercolor
# 3686          scary  watercolor
# 3785          scary         pen
# 3786          scary       comic
# 4094          happy       comic
# 4095          happy       comic
# 4289         gloomy          3d
# 4526          happy   vectorart
# 4582          happy          3d
# 4584          happy          3d
# 4588          scary    oilpaint
# 5059          happy          3d
# 5093         gloomy          3d
# 5100         gloomy          3d
# ...             ...         ...
# 221200907     happy    oilpaint
# 221201617     happy    oilpaint
# 221233893     happy    oilpaint
# 221276915  peaceful    graphite
# 221296465  peaceful   vectorart
# 221311391     happy    oilpaint
# 221317215  peaceful         pen
# 221342417    gloomy          3d
# 221347069     scary       comic
# 221411517  peaceful    oilpaint
# 221422751  peaceful       comic
# 221483739  peaceful    oilpaint
# 221538227  peaceful    oilpaint
# 221615627     happy   vectorart
# 221655649    gloomy          3d
# 221655661  peaceful          3d
# 221666277     happy       comic
# 221710885  peaceful    oilpaint
# 221805041    gloomy         pen
# 221850181  peaceful          3d
# 221853487     happy          3d
# 221866595  peaceful    oilpaint
# 221878323    gloomy       comic
# 221878325  peaceful       comic
# 221878327     happy       comic
# 221878331  peaceful       comic
# 222307913  peaceful    graphite
# 222352655     happy       comic
# 222352657     happy       comic
# 222446005     happy       comic
#
# [372777 rows x 2 columns]

# %% [markdown]
# ## Merging

# %%
result = pd.concat([modules_compressed, labels], axis=1,join='inner')
result.head()
# Out:
#       project_id                                                src   emotion  \
# mid
# 489        40030  https://mir-s3-cdn-cf.behance.net/project_modu...  peaceful
# 1004       40040  https://mir-s3-cdn-cf.behance.net/project_modu...    gloomy
# 1053       40041  https://mir-s3-cdn-cf.behance.net/project_modu...    gloomy
# 1065       40041  https://mir-s3-cdn-cf.behance.net/project_modu...    gloomy
# 1067       40043  https://mir-s3-cdn-cf.behance.net/project_modu...     happy
#
#         medium
# mid
# 489   oilpaint
# 1004  graphite
# 1053  oilpaint
# 1065        3d
# 1067       pen

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 372777 entries, 489 to 222446005
# Data columns (total 4 columns):
# project_id    372777 non-null int32
# src           372777 non-null object
# emotion       372777 non-null category
# medium        372777 non-null category
# dtypes: category(2), int32(1), object(1)
# memory usage: 7.8+ MB

# %%
result.to_pickle('../data/processed_data.pkl')

# %%
opened = pd.read_pickle('../data/processed_data.pkl')
opened.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 372777 entries, 489 to 222446005
# Data columns (total 4 columns):
# project_id    372777 non-null int32
# src           372777 non-null object
# emotion       372777 non-null category
# medium        372777 non-null category
# dtypes: category(2), int32(1), object(1)
# memory usage: 7.8+ MB

# %%
import preprocess
# Out:
# memory used before preprocess:  9.33704
#
# downcasting integers for: ['mid', 'project_id']
#
# reduced memory usage for:   mid          from     3.11 to     1.56
# reduced memory usage for:   project_id   from     3.11 to     1.56
#
# available RAM: svmem(total=8589934592, available=1837469696, percent=78.6, used=5901312000, free=16384000, active=1823080448, inactive=1821085696, wired=2257145856)
# available RAM: svmem(total=8589934592, available=1837637632, percent=78.6, used=5901545472, free=16551936, active=1824714752, inactive=1821085696, wired=2255745024)
#
# memory used after preprocess:  6.22472
# converting emotion                        size:  26.63	->	 3.36
# converting medium                         size:  26.53	->	 3.36

# %% [markdown]
# ## Crowd Source Labels

# %%
crowd_labels = pd.read_sql(
    "select * from crowd_labels",
    connection,
    index_col="mid"
)

# %%
classes = crowd_labels['attribute'].apply(lambda x: x.split('_')[0])

# %%
crowd_labels.loc[classes != "content"].head()
# Out:
#                attribute     label
# mid
# 152469509  emotion_happy  positive
# 115802119  emotion_happy  positive
# 145489929  emotion_happy  positive
# 143785995  emotion_happy  positive
# 99428137   emotion_happy  positive

# %%
crowd_labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 393022 entries, 2588676 to 111747071
# Data columns (total 2 columns):
# attribute    393022 non-null object
# label        393022 non-null object
# dtypes: object(2)
# memory usage: 9.0+ MB

# %%
crowd_labels['attribute'].unique()
# Out:
# array(['content_building', 'emotion_happy', 'content_flower',
#        'content_bicycle', 'media_comic', 'content_people',
#        'media_3d_graphics', 'content_dog', 'media_vectorart',
#        'emotion_scary', 'emotion_gloomy', 'media_graphite',
#        'emotion_peaceful', 'media_pen_ink', 'content_cars',
#        'media_oilpaint', 'content_cat', 'content_tree', 'content_bird',
#        'media_watercolor'], dtype=object)

# %%
crowd_labels = rm.convert_obj_columns_to_cat (crowd_labels, {})

# %%
crowd_labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 393022 entries, 2588676 to 111747071
# Data columns (total 2 columns):
# attribute    393022 non-null category
# label        393022 non-null category
# dtypes: category(2)
# memory usage: 3.7 MB

# %%
crowd_labels.head()
# Out:
#                   attribute     label
# mid
# 2588676    content_building  positive
# 146997253  content_building  positive
# 15663110   content_building  positive
# 15663114   content_building  positive
# 2588684    content_building  positive

# %%
# modules_compressed
crowd_labels.sort_index(inplace=True)

# %%
crowd_labels_merged = pd.concat([modules_compressed, crowd_labels], axis=1,join='inner')
crowd_labels_merged
# Out:
#            project_id                                                src  \
# mid
# 489             40030  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1053            40041  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1065            40041  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1067            40043  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1247            40053  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1248            40053  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1559            40066  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1593            40053  https://mir-s3-cdn-cf.behance.net/project_modu...
# 2240            40168  https://mir-s3-cdn-cf.behance.net/project_modu...
# 2240            40168  https://mir-s3-cdn-cf.behance.net/project_modu...
# 2453            40192  https://mir-s3-cdn-cf.behance.net/project_modu...
# 2460            40193  https://mir-s3-cdn-cf.behance.net/project_modu...
# 2475            40197  https://mir-s3-cdn-cf.behance.net/project_modu...
# 2687            40261  https://mir-s3-cdn-cf.behance.net/project_modu...
# 2694            40261  https://mir-s3-cdn-cf.behance.net/project_modu...
# 2944            40294  https://mir-s3-cdn-cf.behance.net/project_modu...
# 3419            40370  https://mir-s3-cdn-cf.behance.net/project_modu...
# 3608            40375  https://mir-s3-cdn-cf.behance.net/project_modu...
# 3686            40390  https://mir-s3-cdn-cf.behance.net/project_modu...
# 3785            40395  https://mir-s3-cdn-cf.behance.net/project_modu...
# 3785            40395  https://mir-s3-cdn-cf.behance.net/project_modu...
# 3786            40395  https://mir-s3-cdn-cf.behance.net/project_modu...
# 4094            40479  https://mir-s3-cdn-cf.behance.net/project_modu...
# 4095            40479  https://mir-s3-cdn-cf.behance.net/project_modu...
# 4289            40499  https://mir-s3-cdn-cf.behance.net/project_modu...
# 4526            40541  https://mir-s3-cdn-cf.behance.net/project_modu...
# 4582            40551  https://mir-s3-cdn-cf.behance.net/project_modu...
# 4584            40551  https://mir-s3-cdn-cf.behance.net/project_modu...
# 4588            40541  https://mir-s3-cdn-cf.behance.net/project_modu...
# 5058            40634  https://mir-s3-cdn-cf.behance.net/project_modu...
# ...               ...                                                ...
# 221201617    22951447  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221233893    22951447  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221250777     3109607  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221276915    11653149  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221296465    12157309  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221311391    26500833  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221317215    27334029  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221342417    27596373  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221347069    27333385  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221411517     1613315  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221422751    27301041  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221483739    10406887  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221538227    30156851  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221615627    29534987  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221655649    24102131  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221655661    24102131  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221666277     9385957  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221710885     7160915  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221805041       97565  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221850181    28750467  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221853487     4686759  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221866595    18094199  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221878323     6045889  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221878325     6045889  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221878327     6045889  https://mir-s3-cdn-cf.behance.net/project_modu...
# 221878331     6045889  https://mir-s3-cdn-cf.behance.net/project_modu...
# 222307913    26742113  https://mir-s3-cdn-cf.behance.net/project_modu...
# 222352655    27827191  https://mir-s3-cdn-cf.behance.net/project_modu...
# 222352657    27827191  https://mir-s3-cdn-cf.behance.net/project_modu...
# 222446005    29445637  https://mir-s3-cdn-cf.behance.net/project_modu...
#
#                    attribute     label
# mid
# 489         emotion_peaceful  positive
# 1053        emotion_peaceful    unsure
# 1065          emotion_gloomy    unsure
# 1067        emotion_peaceful    unsure
# 1247          media_oilpaint  negative
# 1248           emotion_scary    unsure
# 1559           emotion_scary  positive
# 1593          media_oilpaint    unsure
# 2240        emotion_peaceful  negative
# 2240           emotion_scary  negative
# 2453          media_oilpaint  negative
# 2460           media_pen_ink    unsure
# 2475          media_oilpaint  negative
# 2687          media_oilpaint  negative
# 2694          media_oilpaint  negative
# 2944           media_pen_ink    unsure
# 3419           emotion_scary  negative
# 3608        emotion_peaceful    unsure
# 3686           emotion_scary    unsure
# 3785             media_comic  positive
# 3785           media_pen_ink    unsure
# 3786             media_comic  positive
# 4094             media_comic  positive
# 4095             media_comic  positive
# 4289       media_3d_graphics    unsure
# 4526             media_comic  negative
# 4582       media_3d_graphics    unsure
# 4584       media_3d_graphics    unsure
# 4588           emotion_scary    unsure
# 5058       media_3d_graphics    unsure
# ...                      ...       ...
# 221201617    content_bicycle  positive
# 221233893    content_bicycle  positive
# 221250777     emotion_gloomy    unsure
# 221276915   content_building  positive
# 221296465   emotion_peaceful    unsure
# 221311391       content_bird  negative
# 221317215       content_bird  positive
# 221342417      emotion_happy    unsure
# 221347069     content_flower  negative
# 221411517       content_tree  positive
# 221422751      media_pen_ink    unsure
# 221483739        content_cat  negative
# 221538227      emotion_scary  negative
# 221615627        content_cat  negative
# 221655649   content_building  positive
# 221655661   content_building  positive
# 221666277        media_comic  positive
# 221710885        content_cat  negative
# 221805041      media_pen_ink  positive
# 221850181  media_3d_graphics  positive
# 221853487   content_building  negative
# 221866595     emotion_gloomy    unsure
# 221878323        media_comic  positive
# 221878325        media_comic  positive
# 221878327        media_comic  positive
# 221878331        media_comic  positive
# 222307913       content_bird  negative
# 222352655        media_comic  positive
# 222352657        media_comic  positive
# 222446005   emotion_peaceful    unsure
#
# [393022 rows x 4 columns]

# %%
opened = pd.read_pickle('../data/processed_data_crowd.pkl')
opened.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 393022 entries, 489 to 222446005
# Data columns (total 4 columns):
# project_id    393022 non-null int32
# src           393022 non-null object
# attribute     393022 non-null category
# label         393022 non-null category
# dtypes: category(2), int32(1), object(1)
# memory usage: 8.2+ MB

# %%
opened.head()
# Out:
#       project_id                                                src  \
# mid
# 489        40030  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1053       40041  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1065       40041  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1067       40043  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1247       40053  https://mir-s3-cdn-cf.behance.net/project_modu...
#
#              attribute     label
# mid
# 489   emotion_peaceful  positive
# 1053  emotion_peaceful    unsure
# 1065    emotion_gloomy    unsure
# 1067  emotion_peaceful    unsure
# 1247    media_oilpaint  negative
