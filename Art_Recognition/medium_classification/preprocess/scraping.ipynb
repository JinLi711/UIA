# %%
import pandas as pd
import numpy as np
import urllib
import os

# %%
crowd_data = pd.read_pickle('../data/processed_data_crowd.pkl')

# %%
crowd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 393022 entries, 489 to 222446005
# Data columns (total 4 columns):
# project_id    393022 non-null int32
# src           393022 non-null object
# attribute     393022 non-null category
# label         393022 non-null category
# dtypes: category(2), int32(1), object(1)
# memory usage: 8.2+ MB

# %%
crowd_data.head()
# Out:
#       project_id                                                src  \
# mid
# 489        40030  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1053       40041  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1065       40041  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1067       40043  https://mir-s3-cdn-cf.behance.net/project_modu...
# 1247       40053  https://mir-s3-cdn-cf.behance.net/project_modu...
#
#              attribute     label
# mid
# 489   emotion_peaceful  positive
# 1053  emotion_peaceful    unsure
# 1065    emotion_gloomy    unsure
# 1067  emotion_peaceful    unsure
# 1247    media_oilpaint  negative

# %%
crowd_data['attribute'].unique()
# Out:
# [emotion_peaceful, emotion_gloomy, media_oilpaint, emotion_scary, media_pen_ink, ..., content_people, content_cars, content_tree, content_cat, content_flower]
# Length: 20
# Categories (20, object): [emotion_peaceful, emotion_gloomy, media_oilpaint, emotion_scary, ..., content_cars, content_tree, content_cat, content_flower]

# %%
classes = crowd_data['attribute'].apply(lambda x: x.split('_')[0])
classes.head(10)
# Out:
# mid
# 489     emotion
# 1053    emotion
# 1065    emotion
# 1067    emotion
# 1247      media
# 1248    emotion
# 1559    emotion
# 1593      media
# 2240    emotion
# 2240    emotion
# Name: attribute, dtype: object

# %%
def make_class_dir(df):
    """
    Make the appropriate directories for storing images.
    
    :param df: dataframe 
    :type  df: pandas.core.frame.DataFrame
    """
    
    attributes = list (df['attribute'].unique())
    
    base_dir = "../data/images"
    
    for attribute in attributes:
        directory = os.path.join(base_dir, attribute)
        if not os.path.exists(directory):
            os.makedirs(directory)
            for subdir in ['train', 'valid', 'test']:
                subdirectory = os.path.join(directory, subdir)
                os.makedirs(subdirectory)
                for subdir2 in ['positive', 'unsure', 'negative']:
                    subdirectory2 = os.path.join(subdirectory, subdir2)
                    os.makedirs(subdirectory2)
# list (crowd_data['attribute'].unique())

#make_class_dir(crowd_data)

# %%
def one_dir_download(df, attribute):
    """
    For one directory, download images corresponding to train, validate, test.
    Download it in folders corresponding to its labels.
    
    :param df: dataframe 
    :type  df: pandas.core.frame.DataFrame
    :param attribute: the attribute
    :type  attribute: str
    """
    rows = df[df['attribute'] == attribute]
    
    # 60%, 20%, 20% split
    train, validate, test = np.split(
        rows.sample(frac=1), 
        [int(.6*len(rows)), int(.8*len(rows))]
    )
    
    # small amount for now
    train = train[:500]
    validate = validate[:500]
    test = test[:500]
    
    for set_name in ['train', 'valid', 'test']:
        if set_name == 'train':
            set_df = train
        elif set_name == 'validate':
            set_df = validate
        else:
            set_df = test
            
        for index, row in set_df.iterrows():
#             print (row['src'])
            directory = os.path.join ("../data/images", attribute, set_name)

            for label in ["positive", "negative", "unsure"]:
                if row['label'] == label:
                    try:
                        urllib.request.urlretrieve(
                        row['src'], 
                        os.path.join(directory, label, str (index) + '.png')
                        )
                    except urllib.error.HTTPError:
                        pass
            
    return train, validate, test
        
# train, validate, test = one_dir_download(crowd_data, "media_oilpaint")

# %%
train.head()
# Out:
#            project_id                                                src  \
# mid
# 155171893    23374817  https://mir-s3-cdn-cf.behance.net/project_modu...
# 86585233     12056105  https://mir-s3-cdn-cf.behance.net/project_modu...
# 105322677    15349193  https://mir-s3-cdn-cf.behance.net/project_modu...
# 140901477    20991759  https://mir-s3-cdn-cf.behance.net/project_modu...
# 59318129      7805767  https://mir-s3-cdn-cf.behance.net/project_modu...
#
#                  attribute     label
# mid
# 155171893  media_vectorart    unsure
# 86585233   media_vectorart    unsure
# 105322677  media_vectorart  negative
# 140901477  media_vectorart  negative
# 59318129   media_vectorart  positive

# %%
def download_images(crowd_data):
    """
    Download all wanted images.
    """
    
    classes = crowd_data['attribute'].apply(lambda x: x.split('_')[0])
    
    # remove content classes since we are not classifying content
    rm_content = crowd_data.loc[classes == "media"]
    attributes = list (rm_content['attribute'].unique())
    
    make_class_dir(rm_content)
    
    
    for attribute in attributes:
        train, validate, test = one_dir_download(rm_content, attribute)
        
#     return train

# %%
# download_images(crowd_data)
# Out:
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/a103c43528306.5601b1ca6531c.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/8b06a920603667.562ee1189d197.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/64b8f2564657.56009eae22ab1.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/63c7c724874275.56343ba4da9fc.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/c05c4e12265881.56265ab74a98d.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/1d22bd16959159.562b3add0ed02.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/fd39a49887437.560dbe5ca835e.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/474cc51917009.56011038008da.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/0e43322528404.56017620a5559.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/e1267937628107.56066fe0efc38.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/1d22bd16959159.562b3add0ed02.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/fd39a49887437.560dbe5ca835e.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/474cc51917009.56011038008da.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/0e43322528404.56017620a5559.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/e1267937628107.56066fe0efc38.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/1cc3ee9686841.560d84558fa69.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/af334c16856.55f727744b6a0.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/d353cd214207.5600875ba50a4.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/7130f743036555.560736c542437.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/d3929a20676063.562ef48e71fff.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/968b19250409.5600898bde954.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/5ff63e2164552.56012896d8e54.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/ac106180079.55f72cbe43804.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/e52c6314182555.562809992b46f.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/c1628322647339.563161edeb3b1.png
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/968b19250409.5600898bde954.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/5ff63e2164552.56012896d8e54.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/ac106180079.55f72cbe43804.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/e52c6314182555.562809992b46f.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/c1628322647339.563161edeb3b1.png
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/bec33723537669.56377eae8d3fb.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/ca5a1714085407.5627d1e49013a.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/115a1114881017.5628a290366a6.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/b96aef54046819.56092c3471112.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/dc287524289457.5633238f3e817.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/73a98e9719.55f726ef39443.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/32732a11992267.5625647380e77.png
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/0f84b720667837.562ef2653ddad.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/db4a8d18954707.562d2309679f1.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/34478b22760103.56317ec720782.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/73a98e9719.55f726ef39443.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/32732a11992267.5625647380e77.png
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/0f84b720667837.562ef2653ddad.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/db4a8d18954707.562d2309679f1.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/34478b22760103.56317ec720782.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp/bcf59f8459911.560bdba90ee54.jpg
# https://mir-s3-cdn-cf.behance.net/project_modules/disp