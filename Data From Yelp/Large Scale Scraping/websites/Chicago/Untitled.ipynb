# %%
import csv
websites = []
for line in open('Cook_County_Websites.csv'):
    websites.append (line.split(',')[1].rstrip())
tuple (websites)
# Out:
# ('https://www.yelp.com/search?find_desc=cafe&find_loc=31620',
#  'https://www.yelp.com/search?find_desc=cafe&find_loc=31627',
#  'https://www.yelp.com/search?find_desc=cafe&find_loc=31637',
#  'https://www.yelp.com/search?find_desc=cafe&find_loc=31647',
#  'https://www.yelp.com/search?find_desc=cafe&find_loc=55604',
#  'https://www.yelp.com/search?find_desc=cafe&find_loc=55605',
#  'https://www.yelp.com/search?find_desc=cafe&find_loc=55606',
#  'https://www.yelp.com/search?find_desc=cafe&find_loc=55612',
#  'https://www.yelp.com/search?find_desc=cafe&find_loc=55613',
#  'https://www.yelp.com/search?find_desc=cafe&find_loc=55615',
#  'https://www.yelp.com/search?find_desc=cafe&find_loc=60004',
#  'https://www.yelp.com/search?find_desc=cafe&find_loc=60005',
#  'https://www.yelp.com/search?find_desc=cafe&find_loc=60006',
#  'https://www.yelp.com/search?find_desc=cafe&find_loc=60007',
#  'https://www.yelp.com/search?find_desc=cafe&find_loc=60008',
# ...
