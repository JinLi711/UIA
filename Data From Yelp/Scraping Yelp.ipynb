# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import re

# %%
'''
    Go to starting page.
    Gather all the links in that one page.
    Go to next page.
    Repeat.
    Stop when the page does not exist. 
        Problem: the page exists even when it shouldn't
        Example: searching &start=1000 seems to produce the first page
        Solution: need to create a numpy array of links,
            append the new links if the new links are not found
            stop if the links are found
        Current Solution (going to change this): 
            Specify a limit
'''

# %%
def gather_Yelp_data(url, cap_num):
    """
        Given a starting url and a page limit,
        gather all the links to businesses.
        Go to the next page.
        Gather all links.
        Repeat a specified number of times.
        Return a numpy array of all links gathered.
    """
    item_number = 1
    websites = np.array([])
    while item_number <= cap_num:
        try:
            html = urlopen(url + "&start=" + str(item_number*10))
            bs = BeautifulSoup(html.read(), 'lxml')
            links = bs.findAll('a', {'class': "biz-name js-analytics-click"})
            for link in links:
                link_string = link.attrs['href']
                websites = np.append(websites, np.array([link_string]))
        except:
            pass
        item_number += 1
    return websites
starturl = """https://www.yelp.com/search?find_desc=cafe&find_loc=Chicago,+IL+60637"""
sites = gather_Yelp_data(starturl, 3)
sites
# Out:
# array(['/adredir?ad_business_id=TxXC31nSy249Oe-AJKagTQ&campaign_id=bfAMUIFasowO9I-Qp6u3EA&click_origin=search_results&placement=above_search&redirect_url=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Fzanzibar-cafe-chicago&request_id=456b97e9f0fa7815&signature=d79026743d6a2120d924a7e42fe4853160d7286ad27249e2cc30f211c5938151&slot=0',
#        '/biz/sip-and-savor-chicago?osq=cafe',
#        '/biz/ex-libris-chicago?osq=cafe',
#        '/biz/pret-a-manger-chicago-17?osq=cafe',
#        '/biz/teamo-boba-bar-chicago-3?osq=cafe',
#        '/biz/truenorth-cafe-hyde-park-chicago-2?osq=cafe',
#        '/biz/chef-saras-cafe-chicago?osq=cafe',
#        '/biz/kusanya-cafe-chicago?osq=cafe',
#        '/biz/bridgeport-coffee-chicago-2?osq=cafe',
#        '/biz/midway-market-chicago?osq=cafe',
#        '/biz/sip-and-savor-chicago-3?osq=cafe',
#        '/adredir?ad_business_id=TxXC31nSy249Oe-AJKagTQ&campaign_id=bfAMUIFasowO9I-Qp6u3EA&click_origin=search_results&placement=above_search&redirect_url=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Fzanzibar-cafe-chicago&request_id=0a801bf2ca85abb7&signature=35d4f8450e270559ceed77fd3a99aa68db0ba036eba208d1b02affa2293e2480&slot=0',
#        '/biz/carver-47-cafe-chicago?osq=cafe',
#        '/biz/aint-she-sweet-cafe-chicago?osq=cafe',
#        '/biz/the-university-of-chicago-bookstore-cafe-chicago?osq=cafe',
#        '/biz/stonys-palace-cafe-chicago?osq=cafe',
#        '/biz/starbucks-chicago-316?osq=cafe',
#        '/biz/starbucks-chicago-122?osq=cafe',
#        '/biz/spoken-word-cafe-chicago?osq=cafe',
#        '/biz/heritage-cafe-chicago?osq=cafe',
#        '/biz/starbucks-chicago-185?osq=cafe',
#        '/biz/cobb-coffee-shop-chicago?osq=cafe',
#        '/adredir?ad_business_id=TxXC31nSy249Oe-AJKagTQ&campaign_id=bfAMUIFasowO9I-Qp6u3EA&click_origin=search_results&placement=above_search&redirect_url=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Fzanzibar-cafe-chicago&request_id=74d937e768f93ccf&signature=6ca125c1d12da46ba4ea15de831d760be32d1c7ca48e357d70319e346e40ea9a&slot=0',
#        '/biz/crack-in-the-cup-coffee-and-tea-chicago?osq=cafe',
#        '/biz/einstein-bros-bagels-chicago-23?osq=cafe',
#        '/biz/classics-cafe-chicago?osq=cafe',
#        '/biz/starbucks-chicago-195?osq=cafe',
#        '/biz/bake-for-me-chicago-3?osq=cafe',
#        '/biz/cis-cafe-chicago?osq=cafe',
#        '/biz/dunkin-donuts-chicago-321?osq=cafe',
#        '/biz/uncle-joes-coffee-bar-and-lounge-chicago?osq=cafe',
#        '/biz/bio-cafe-chicago?osq=cafe',
#        '/biz/jazzmans-cafe-and-bakery-chicago-4?osq=cafe'], dtype='<U312')

# %%
"""
    Scraping an individual business:
    Information that I want:
        Address
        Pricing
        Health Score
        Extra info on the right
        Reviews
"""
def getBasicInfo(url):
    """
        Given url of one business,
        gather all basic info except the reviews.
        Returns a dictionary.
    """
    dict_of_info = {}
    html = urlopen(url)
    bs = BeautifulSoup(html.read(), 'lxml')
    dict_of_info['Address'] = bs.find_all('address')[-1].text
    price_and_health = bs.find_all('dd', {'class': 'nowrap'})
    dict_of_info['Price Range'] = price_and_health[0].text
    try:
        dict_of_info['Health Score'] = price_and_health[1].text
    except:
        pass
    more_biz_info = bs.find('div', {'class': "short-def-list"}).find_all('dl',)
    for info in more_biz_info:
        dict_of_info[info.find('dt').text] = info.find('dd').text
    return dict_of_info

greenline_coffee = """https://www.yelp.com/biz/greenline-coffee-chicago"""
greenline = getBasicInfo(greenline_coffee)

# %%
def clear_white_space(i_dict):
    for key in i_dict.keys():
        i_dict[key.strip()] = i_dict.pop(key)
    for key in i_dict.keys():
        i_dict[key] = i_dict[key].strip()
    return i_dict

greenline = clear_white_space(clear_white_space (greenline)) # clear it twice
greenline
# Out:
# {'Accepts Apple Pay': 'No',
#  'Accepts Credit Cards': 'Yes',
#  'Accepts Google Pay': 'No',
#  'Address': '501 E 61st StChicago, IL 60637',
#  'Bike Parking': 'Yes',
#  'Caters': 'No',
#  'Gender Neutral Restrooms': 'Yes',
#  'Good for Working': 'Yes',
#  'Health Score': '95 out of 100',
#  'Outdoor Seating': 'Yes',
#  'Parking': 'Street, Private Lot',
#  'Price Range': 'Inexpensive',
#  'Take-out': 'Yes',
#  'Wheelchair Accessible': 'Yes',
#  'Wi-Fi': 'Free'}

# %%
"""
    Now to get the reviews:
    Want:
        star number
        date
        content
"""
def get_reviews_in_single_page(bs):
    """
        Given a parsed url,
        get all review info in a single page.
        Returns a df.
    """
    review_dict = {}
    # this gets the box of info of Yelp review
    review_form = bs.find(
        'ul', {'class': "ylist ylist-bordered reviews"}
        ).find_all(
        'div', {'class': "review-wrapper"})

    rating_list = []
    date_list = []
    comment_list = []
    for review in review_form[1:]:
        # gets number of stars
        rating_list.append(
            review.find('div', {'class': re.compile('i-stars i-stars--regular-.*')}).img.attrs['alt'])
        # gets dates
        date_list.append(
            review.find('span', {'class': "rating-qualifier"}).text)
        # gets comments
        comment_list.append(
            review.find('p', {'lang': "en"}).text)
    review_dict['Star Ratings'] = rating_list
    review_dict['Date'] = date_list
    review_dict['Comment'] = comment_list   
    return pd.DataFrame(review_dict)

# %%
def get_all_reviews(url, page_limit):
    page_num = 0
    review_df = pd.DataFrame()
    review_url = url
    while page_num <= page_limit:
        html = urlopen(review_url)
        bs = BeautifulSoup(html.read(), 'lxml')
        review_df = review_df.append(get_reviews_in_single_page(bs))
        page_num += 1
        review_url = url + '?start=' + str(page_num * 20)  # 20 reviews in each page
    review_df = review_df.drop_duplicates(['Comment'])  # .reset_index().drop('index',axis=1)
    return review_df

greenline_coffee_reviews = get_all_reviews(greenline_coffee, 2)
greenline_coffee_reviews
# Out:
#                                               Comment  \
# 0   Excited to find this chill space! Great friend...
# 1   This place is AWESOME!I was so hungry I gobble...
# 2   I love this place and what it's trying to do f...
# 3   This winter season has been very mild in compa...
# 4   Very good coffee. Affordable and local, cant b...
# 5   I really enjoy bringing my work and sipping an...
# 6   An oasis in the dessert! This is a nice, clean...
# 7   Pros: Very friendly ambiance especially if you...
# 8   This place is a great local coffee shop locate...
# 9   My coffee (caramel macchiato)tasted exactly th...
# 10  Open till 7 this summer. Crafting in Public ev...
# 11  Really wonderful place! The staff is terrific ...
# 12  Looking for an awesome cafe with great drinks ...
# 13  This is a nice cozy cafe, I enjoy the abeyance...
# 14  This is a great coffee shop.  They have good d...
# 15  A picture is a worth a thousand words and I po...
# 16  The atmosphere at Greenline Coffee is wonderfu...
# 17  I was getting a little unnerved at first on my...
# 18  Atmosphere - 5 Stars: The atmosphere in the ca...
# 19  Love, love, love this place. It's a great plac...
# 0   Came here three time already and this is my re...
# 1   It was literally love at first sight and bite....
# 2   So, this place is NOT in Hyde Park as the othe...
# 3   Clean, spacious, excellent seating, delicious ...
# 4   Today I tried the mango smoothie while attendi...
# 5   I love the decadent pastries and  the caramel ...
# 6   Sugar WAFFLES, the PERFECT compliment to quali...
# 7   Always looking for a good coffee spot, and thi...
# 8   I'm a huge fan of Greenline Coffee..the only r...
# 9   The best about this place? The staff. Always c...
# 10        Great space, lovely staff, delicious coffee
# 11  This is a fantastic spot. Cinnamon nut coffee ...
# 12  A nice and quiet spot on the south side. Went ...
# 13  Most definitely a fan. It's a great coffee sho...
# 14  Great food and great service. Even just when y...
# 15  Amazing sugar waffles! Great atmosphere, with ...
# 16  Truly a diamond in the ruff! The absolute best...
# 17  Fantastic cafe! Beautiful space, great for doi...
# 18  I am stopping at this shop as much as I can.  ...
# 19  Sunshine Gospel Ministries is near and dear to...
# 0   One of my fav places to stop at in Woodlawn. G...
# 1   I don't drink coffee but I adore this place. B...
# 2   Great place . Friendly staff . Coffee is very ...
# 3   They get 5 stars for offering me a ceramic mug...
# 4   Greenline is an excellent coffee shop, I highl...
# 5   Excited about my first visit to Greenline Coff...
# 6   The Greenline Coffee house is the place to go....
# 7   Met up with a friend before work for coffee an...
# 8   Love it! Breakfast veggie sandwich was yummy, ...
# 9   Oh man. The best - this neighborhood needed a ...
# 10  This place is absolutely amazing! I love check...
#
#                           Date     Star Ratings
# 0    \n        7/14/2018\n      5.0 star rating
# 1     \n        9/8/2017\n      5.0 star rating
# 2    \n        4/13/2018\n      5.0 star rating
# 3    \n        2/23/2016\n      4.0 star rating
# 4     \n        1/8/2018\n      5.0 star rating
# 5    \n        6/22/2017\n      5.0 star rating
# 6    \n        5/19/2018\n      5.0 star rating
# 7    \n        3/10/2016\n      5.0 star rating
# 8     \n        8/9/2017\n      4.0 star rating
# 9    \n        8/18/2017\n      1.0 star rating
# 10   \n        5/12/2017\n      5.0 star rating
# 11  \n        11/12/2016\n      5.0 star rating
# 12   \n        3/28/2016\n      4.0 star rating
# 13    \n        4/6/2017\n      4.0 star rating
# 14   \n        12/8/2014\n      5.0 star rating
# 15   \n        8/22/2014\n      5.0 star rating
# 16   \n        8/11/2014\n      5.0 star rating
# 17   \n        2/29/2016\n      4.0 star rating
# 18  \n        10/26/2015\n      4.0 star rating
# 19   \n        6/27/2016\n      5.0 star rating
# 0    \n        5/30/2015\n      2.0 star rating
# 1    \n        5/20/2015\n      5.0 star rating
# 2    \n        4/22/2017\n      4.0 star rating
# 3     \n        1/3/2015\n      5.0 star rating
# 4    \n        7/16/2016\n      4.0 star rating
# 5    \n        4/27/2016\n      5.0 star rating
# 6     \n        9/6/2014\n      5.0 star rating
# 7    \n        3/26/2016\n      5.0 star rating
# 8    \n        7/23/2015\n      4.0 star rating
# 9   \n        11/10/2014\n      4.0 star rating
# 10   \n        2/18/2016\n      4.0 star rating
# 11   \n        10/7/2015\n      5.0 star rating
# 12   \n        1/27/2016\n      5.0 star rating
# 13   \n        2/28/2015\n      4.0 star rating
# 14    \n        9/4/2015\n      5.0 star rating
# 15   \n        9/16/2015\n      5.0 star rating
# 16  \n        10/11/2014\n      5.0 star rating
# 17   \n        2/28/2015\n      5.0 star rating
# 18   \n        3/24/2015\n      3.0 star rating
# 19   \n        1/22/2015\n      5.0 star rating
# 0    \n        4/15/2015\n      5.0 star rating
# 1   \n        12/15/2014\n      5.0 star rating
# 2    \n        1/26/2015\n      5.0 star rating
# 3   \n        11/21/2014\n      5.0 star rating
# 4    \n        7/23/2015\n      5.0 star rating
# 5    \n        3/16/2016\n      3.0 star rating
# 6   \n        10/15/2014\n      5.0 star rating
# 7   \n        10/24/2014\n      5.0 star rating
# 8    \n        7/14/2015\n      5.0 star rating
# 9    \n        10/3/2014\n      5.0 star rating
# 10   \n        2/23/2015\n      5.0 star rating

# %%
# Test code on a different business
sanc_url = """https://www.yelp.com/biz/sanctuary-cafe-chicago?osq=cafe"""
sanctuary_cafe = getBasicInfo(sanc_url)
sanctuary_cafe = clear_white_space(clear_white_space(sanctuary_cafe))
sanctuary_cafe
# Out:
# {'Accepts Apple Pay': 'Yes',
#  'Accepts Bitcoin': 'No',
#  'Accepts Credit Cards': 'Yes',
#  'Accepts Google Pay': 'No',
#  'Address': '5655 S University AveChicago, IL 60637',
#  'Alcohol': 'No',
#  'Ambience': 'Casual',
#  'Attire': 'Casual',
#  'Bike Parking': 'Yes',
#  'Cannabis Products': 'No',
#  'Caters': 'Yes',
#  'Delivery': 'Yes',
#  'Dogs Allowed': 'No',
#  'Gender Neutral Restrooms': 'Yes',
#  'Good For': 'Dessert',
#  'Good for Groups': 'Yes',
#  'Good for Kids': 'Yes',
#  'Good for Working': 'Yes',
#  'Has TV': 'No',
#  'Noise Level': 'Quiet',
#  'Outdoor Seating': 'No',
#  'Parking': 'Street',
#  'Price Range': 'Under $10',
#  'Take-out': 'Yes',
#  'Takes Reservations': 'No',
#  'Waiter Service': 'No',
#  'Wheelchair Accessible': 'Yes',
#  'Wi-Fi': 'Free'}

# %%
sanctuary_cafe_reviews = get_all_reviews(sanc_url, 2)
sanctuary_cafe_reviews
# Out:
#                                               Comment  \
# 0   Cinnamon roll and cakes are incredible! Their ...
# 1   Popped in here for a quick cup of coffee while...
# 2   A fun cafe with a nice vibe and the perfect pl...
# 3   Love this place and what they stand for. Tried...
# 4   While looking for an online menu, I found info...
# 5   I was expecting another cafe similar to Fabian...
# 6   I love this space! Light, airy, clean and a gr...
# 7   I was so excited to finally try this cafe, as ...
# 8   Sanctuary Cafe is a lovely place to study or g...
# 9   Love this place.  Good selection of savory and...
# 10  I have had quiche before, but this is by far t...
# 11  Amazing quiches!! Cool atmosphere.  Right on c...
# 12  This is a great and secret find. At Sanctuary ...
# 13  I love Sanctuary Cafe! The coffee and food ite...
# 14  Incredibly comfortable environment, friendly w...
#
#                           Date     Star Ratings
# 0   \n        10/10/2018\n      5.0 star rating
# 1    \n        4/24/2018\n      3.0 star rating
# 2    \n        9/28/2018\n      5.0 star rating
# 3     \n        9/9/2018\n      5.0 star rating
# 4    \n        8/16/2017\n      5.0 star rating
# 5    \n        7/24/2017\n      3.0 star rating
# 6    \n        9/15/2017\n      5.0 star rating
# 7     \n        5/8/2018\n      2.0 star rating
# 8    \n        1/16/2018\n      5.0 star rating
# 9     \n        3/6/2018\n      5.0 star rating
# 10    \n        8/8/2017\n      5.0 star rating
# 11  \n        12/18/2017\n      5.0 star rating
# 12    \n        9/5/2017\n      5.0 star rating
# 13   \n        6/29/2017\n      5.0 star rating
# 14   \n        6/11/2017\n      4.0 star rating
