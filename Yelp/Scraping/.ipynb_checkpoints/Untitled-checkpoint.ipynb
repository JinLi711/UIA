# %%
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_names = glob.glob("Zip Code Data (Raw)/*.csv")
def open_filter_files (files):
    """
        Given a list of files, return a dataframe, 
        where each column is a zip code, 
        and each row is filtered by some key words
    """
    keywords = pd.DataFrame ()
    websites = pd.DataFrame ()
    for file in files:
        csv = pd.read_csv (file)
        name = file.strip('Zip Code Data (Raw)/').strip('.csv')
        col = [
            'category-str-list', 'category-str-list 2',
            'category-str-list 3', 'category-str-list 4']
        cat = csv [col].replace(np.nan, '', regex=True)
        cat[name] = cat [col[0]].astype(str) + cat [col[1]] + cat [col[2]] + cat [col[3]]
        cat[name].str.strip()
        keywords = pd.concat ([keywords, cat [name]], axis=1)
        
        csv.rename(index=str, columns = {'js-analytics-click href': file})
        websites = pd.concat ([websites, csv [file]], axis=1)
        #websites = pd.concat ([websites, csv ['js-analytics-click href']], axis=1)
    return (websites, keywords)
    #return df #pd.DataFrame (cat [name])
websites, keywords = open_filter_files (file_names)
websites
# Out:
#                                js-analytics-click href  \
# 0    https://www.yelp.com/biz/around-cafe-arlington...
# 1    https://www.yelp.com/biz/coquelicot-gallery-an...
# 2    https://www.yelp.com/biz/uptown-cafe-arlington...
# 3    https://www.yelp.com/biz/bread-and-butter-cafe...
# 4    https://www.yelp.com/biz/christies-dairy-delig...
# 5    https://www.yelp.com/biz/cafe-de-oro-riverwood...
# 6    https://www.yelp.com/biz/the-bakester-arlingto...
# 7    https://www.yelp.com/biz/honey-jam-cafe-arling...
# 8    https://www.yelp.com/biz/purple-sprout-cafe-wh...
# 9    https://www.yelp.com/biz/jelly-cafe-mount-pros...
# 10   https://www.yelp.com/biz/morning-blend-mount-p...
# 11   https://www.yelp.com/biz/kira-euro-deli-arling...
# 12   https://www.yelp.com/biz/releaf-matcha-caf%C3%...
# 13   https://www.yelp.com/biz/tous-les-jours-schaum...
# 14   https://www.yelp.com/biz/quarter-pole-coffee-a...
# 15   https://www.yelp.com/biz/long-grove-coffee-lon...
# 16   https://www.yelp.com/biz/local-coffee-tea-and-...
# 17   https://www.yelp.com/biz/starbucks-arlington-h...
# 18   https://www.yelp.com/biz/handsome-bakery-and-c...
# 19   https://www.yelp.com/biz/covered-bridge-creame...
# 20   https://www.yelp.com/biz/jazz-cafe-wheeling?os...
# 21   https://www.yelp.com/biz/spunky-dunkers-arling...
# 22   https://www.yelp.com/biz/spunky-dunkers-donuts...
# 23   https://www.yelp.com/biz/starbucks-arlington-h...
# 24   https://www.yelp.com/biz/donut-drop-schaumburg...
# 25   https://www.yelp.com/biz/starbucks-palatine-6?...
# 26   https://www.yelp.com/biz/stans-donuts-and-coff...
# 27   https://www.yelp.com/biz/starbucks-arlington-h...
# 28   https://www.yelp.com/biz/java-junction-buffalo...
# 29   https://www.yelp.com/biz/jazzmans-cafe-and-bak...
# ..                                                 ...
# 111  https://www.yelp.com/biz/mcdonalds-rolling-mea...
# 112  https://www.yelp.com/biz/7-eleven-buffalo-grov...
# 113  https://www.yelp.com/biz/dunkin-donuts-baskin-...
# 114  https://www.yelp.com/biz/7-eleven-des-plaines?...
# 115  https://www.yelp.com/biz/winter-garden-caf%C3%...
# 116  https://www.yelp.com/biz/dunkin-donuts-mount-p...
# 117  https://www.yelp.com/biz/illy-lincolnshire?osq...
# 118  https://www.yelp.com/biz/the-muffin-bar-mount-...
